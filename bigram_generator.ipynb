# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import nltk
nltk.download('averaged_perceptron_tagger')
import numpy as np
from nltk.corpus import stopwords
import string
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mac/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
#importing the data set 

df=pd.read_csv("/Users/siddharthsaxena/Desktop/final_set.csv")

# %%
#dropping the duplicates comments

df=df.drop_duplicates(keep="first")

#splitting the data frame based on the model of the phone 

df_6t=df[df['Model']=='6t']
df_s10=df[df['Model']=='s10']
df_pixel3=df[df['Model']=='pixel3']
df_xs=df[df['Model']=='xs']

# %%
def tokenize(text2):
    # takes a list of comment strings and tokenizes
    new=[]
    tokens=[]
    count=0
    for text in text2:
        pattern=r'\w[\w\'-]*\w'      
        tokens=nltk.regexp_tokenize(text, pattern)
        tokens=[tokens.lower() for tokens in tokens]
        new+=tokens 
        count+=1
    return nltk.pos_tag(new)

# %%
tagged_tokens = tokenize (df_s10["commentText"])

# %%
#creating bigrams on the tagged_tokens

bigrams=list(nltk.bigrams(tagged_tokens))

# gives bigrams where nouns are followed by adj

phrases=[ (x[0] + ' ' + y[0]) for (x,y) in bigrams \
         if x[1].startswith('JJ' or 'JJS' or 'JJR') \
         and y[1].startswith('NN' or 'NNP' or 'NNS' or 'NNPS')]

phrases
# Out:
# ['favorite smartphone',
#  'girl hands',
#  'lol samsung',
#  'exact phone',
#  'same phone',
#  'punch hole',
#  'better favorite',
#  'galaxy s10',
#  'same phone',
#  'good things',
#  'notice lot',
#  'mere fact',
#  'latest phones',
#  'gimmicky ones',
#  'secondary swipe',
#  'tip wireless',
#  'same phone',
#  'dead cool',
#  'double swipe',
#  's10 cool',
#  'unbox therapy',
#  'ikon fortnite',
#  'bixby button',
#  'different apps',
#  'single press',
#  'double press',
#  'single press',
#  'google pay',
#  'double press',
#  'other voice',
#  'more years',
#  'android quality',
#  'cowboy boots',
#  'bryan concert',
#  'luke bryan',
#  'fake country',
#  'much samsung',
#  'good lmfaoo',
#  'android os',
#  'long time',
#  'same anybody',
#  's9 problems',
#  'virtual button',
#  'easy access',
#  'curved display',
#  'tempered glass',
#  "there's setting",
#  'extra seioe6',
#  'google maps',
#  'kept half',
#  'open bixby',
#  'latest device',
#  'sophisticated security',
#  'pro hacker',
#  "ex hubby's",
#  "sure he's",
#  'successful internet',
#  "i'm testament",
#  'real question',
#  'next gen',
#  's10 battery',
#  'video porn',
#  'few upgrades',
#  'new tech',
#  'newer phones',
#  'big joke',
#  'own channel',
#  "big there's",
#  'bixby button',
#  'best gadgets',
#  'new products',
#  'top down',
#  'least years',
#  'fortnite message',
#  'xer0skill twitter',
#  "swipe isn't",
#  "oneplus's implementation",
#  'only reason',
#  'worst samsung',
#  'fingerprint scanner',
#  'smart lock',
#  'samsung pay',
#  'unbox therapy',
#  'extra cash',
#  'bad experience',
#  'samsung galaxy',
#  'unbox therapy',
#  'samsung products',
#  'new technology',
#  'yo code',
#  'small af',
#  'full hand',
#  'favorite phone',
#  'unprofessional review',
#  'unboxing video',
#  'unbox therapy',
#  'unbox therapy',
#  'other youtuber',
#  'punch holes',
#  'whole corner',
#  'same effect',
#  'stupid idea',
#  'super damn',
#  'lemme flex',
#  'internal storage',
#  'ram quad',
#  'unlock situation',
#  'favourite vloger',
#  'unbox therapy',
#  'different eyes',
#  'present samsung',
#  'unbox therapy',
#  'green think',
#  'more colours',
#  'stainless steel',
#  'old gold',
#  'light gold',
#  'app store',
#  'lag issues',
#  'accidental turning',
#  'cool stuff',
#  'gym button',
#  'distracted enables',
#  'gym music',
#  'routine image',
#  'nice sony',
#  'good price',
#  'ww2 imagine',
#  'bro aliens',
#  'microsoft phone',
#  'good phones',
#  'bad thing',
#  'secondary swipe',
#  'mobile videographer',
#  's10e battery',
#  'bigger battery',
#  'new designs',
#  'only thing',
#  'dark mode',
#  'microsoft lumia',
#  'good phone',
#  'high-mid tier',
#  'chinese phone',
#  'leagao lead',
#  'other phones',
#  'own battery',
#  'mah battery',
#  'social media',
#  "i'm barber",
#  'sd card',
#  'next morning',
#  'future guys',
#  'double drop',
#  'long time',
#  'awful apps',
#  'samsung pay',
#  'dont mean',
#  'complete silent',
#  'shitty quality',
#  'ridiculous apple',
#  'bigger chin',
#  'hole punch',
#  'forehead area',
#  'whole video',
#  'new note',
#  'facial recognition',
#  'single click',
#  'double click',
#  'hard giveaways',
#  'yeah yeah',
#  'best ui',
#  'few things',
#  'multi-app windows',
#  'different angles',
#  'multiple camera',
#  'future updates',
#  'democratic solution',
#  'new samsung',
#  'larger icons',
#  'more screen',
#  'less borders',
#  'easier use',
#  'overall experience',
#  'better samsung',
#  'best hi',
#  'press hold',
#  'next week',
#  'past iphone',
#  'back round',
#  'lol don',
#  'other angle',
#  'expensive phone',
#  'good idea',
#  'certain type',
#  'dont guys',
#  'rectangular bar',
#  'favorite youtuber',
#  's10 plus',
#  'xs max',
#  'dark screen',
#  'more speedy',
#  'current phone',
#  'galaxy note',
#  "unboxing i'm",
#  'only thing',
#  'text call',
#  'ui android',
#  'update samsung',
#  'note s10',
#  'honest opinions',
#  'real estate',
#  'airplane taxi',
#  'past settings',
#  'fucking settings',
#  'fav device',
#  'physical button',
#  'screen corners',
#  'active lol',
#  'wrong iphone',
#  'funny guy',
#  'yellow orange',
#  'right people',
#  'certain kind',
#  'unlock functions',
#  'wasted time',
#  's9 months',
#  'double swipe',
#  'forth hahahha',
#  'facial recognition',
#  'bad thing',
#  'only thing',
#  'call logs',
#  'call logs',
#  'own please',
#  'fortnite skin',
#  'galaxy s10',
#  'double swipe',
#  'nice review',
#  'ultra power',
#  'dark mode',
#  'quick settings',
#  'useless unlock',
#  'same pile',
#  'shit infinity',
#  'ir blaster',
#  'new phones',
#  'current phone',
#  'current phone',
#  'more years',
#  'micro expressions',
#  'subconscious body',
#  'new technology',
#  'smart phones',
#  'stuck apple',
#  'vid bro',
#  'fragile plastic',
#  'sim card',
#  'resistant alot',
#  'samsung device',
#  'many times',
#  'sim card',
#  'sd card',
#  'funny things',
#  'bright sunlight',
#  'manual brightness',
#  'manual brightness',
#  'high brightness',
#  'short time',
#  'little burn-ins',
#  'maximum brightness',
#  'bionic performance',
#  'updates alot',
#  'apps games',
#  'scan stay',
#  'smart phones',
#  'mean shitdroids',
#  'best processor',
#  'same thing',
#  'fan boys',
#  'different reading',
#  'normal s10',
#  'ten years',
#  'big icons',
#  'top bar',
#  'other launchers',
#  'pixel xl',
#  'white colour',
#  "thought i'd",
#  'curved edge',
#  'galaxy note',
#  'old oneplus',
#  'unbox therapy',
#  'unbox therapy',
#  'unbox therapy',
#  'more subscribers',
#  'huawei p20',
#  'nice phone',
#  'unbox therapy',
#  'natural intuition',
#  'many respects',
#  'swipe thing',
#  'older devices',
#  'same thing',
#  'most phones',
#  'different camera',
#  'more years',
#  'socialist states',
#  's10 smooth',
#  'bixby button',
#  'first minutes',
#  'second swipe',
#  'more settings',
#  'wish buttons',
#  'oh thats',
#  'new york',
#  'many phones',
#  'lgv30 finger',
#  'fire wish',
#  "can't wait",
#  'mine apple',
#  'double swipe',
#  'samsung lunch',
#  'new phone',
#  'same shit',
#  'added things',
#  'shitt wait',
#  'own apps',
#  "nightmare i'm",
#  'galaxy s7',
#  'few years',
#  "it's case",
#  'sound quality',
#  "didn't drop",
#  'new s10',
#  'current phone',
#  'dam dude',
#  'serious millions',
#  'crazy hope',
#  'many years',
#  'next phone',
#  'adjustable buttons',
#  'next years',
#  'visual experience',
#  'galaxy s8',
#  "fantastic i'm",
#  "don't press",
#  'much quicker',
#  'filthy dirty',
#  'updated everyone',
#  'oneplus phone',
#  'only difference',
#  'meaningful changes',
#  'new shift',
#  'big future',
#  'unbox therapy',
#  'big screen',
#  'same pull',
#  'new technology',
#  'brilliant phone',
#  'fortnite code',
#  'exclusive skin',
#  'great vids',
#  'developer mode',
#  'nokia keypad',
#  'samsung phones',
#  'emui clone',
#  'facial recognition',
#  'motoz force',
#  'secondary swipe',
#  'easier reach',
#  'redmi note',
#  'dark mode',
#  'nice vid',
#  'dark themes',
#  'less eye',
#  'programmable button',
#  "live couldn't",
#  'advanced editor',
#  'unbelievable hate',
#  'terabyte space',
#  'better battery',
#  'full price',
#  'standard today',
#  'new phone',
#  'ultrasonic part',
#  's8 wait',
#  'samsung note',
#  'full eco-system',
#  'new cameras',
#  'bigger sensors',
#  'dirty hands',
#  'finger tips',
#  'burito upwards',
#  'ui apple',
#  'new iphone',
#  'usual iphone',
#  's10 hope',
#  's10 galaxy',
#  'samsung fan',
#  'great software',
#  'last year',
#  'mobile device',
#  's10 fingerprint',
#  'android phones',
#  'customizable ui',
#  'particular aspect',
#  'unlock procedure',
#  'same step',
#  "s10's version",
#  'other devices',
#  'great channel',
#  'tech youtuber',
#  'different software',
#  'new phone',
#  'good lol',
#  'watch couple',
#  'smart switch',
#  'apologetic customer',
#  'speciallist excuse',
#  'rich kids',
#  'one-handed use',
#  'don mind',
#  'tiny bezels',
#  'real estate',
#  'tiny edge',
#  'only one',
#  'much sleeker',
#  'mean airpods',
#  'same way',
#  'last phone',
#  'gonna buy',
#  'only issue',
#  'decent pair',
#  'bluetooth headphones',
#  'next model',
#  'thumb fingerprint',
#  'sonic sensor',
#  'long hold',
#  'newest version',
#  'huge battery',
#  'bigger issue',
#  'android soooo',
#  'front fuck',
#  'more money',
#  'screen space',
#  'android fucktards',
#  'bright galaxy',
#  'ideal dream',
#  'yrs samsung',
#  'funny today',
#  'pal hahaha',
#  'great vid',
#  'great work',
#  'ikonik skin',
#  'tech channel',
#  'new software',
#  'same trash',
#  'galaxy s7',
#  'new samsung',
#  'unbox therapy',
#  'fantastic review',
#  'amazing samsung',
#  'high bro',
#  'facial unlock',
#  's10 lineup',
#  'facial recognition',
#  'second swipe',
#  'direct face',
#  'sonic sensor',
#  'ur thumb',
#  'old operating',
#  'outrageous price',
#  'previous versions',
#  'much samsung',
#  'ui update',
#  'big upgrade',
#  'ui ughhhhhhhhhh',
#  'highlighted circles',
#  'screen protection',
#  'worst part',
#  'different utility',
#  'major hiccup',
#  'pure android',
#  'sonic fps',
#  'transparent front',
#  'next generation',
#  'screen fingerprint',
#  'swipe thing',
#  'nokia pure',
#  'secondary swipe',
#  'dark mode',
#  "wow i'm",
#  'ultrasonic sensor',
#  'wrong woww',
#  'oneplus fans',
#  'unlock process',
#  'nokia9 plz',
#  'quick touch',
#  'love samsung',
#  'da faq',
#  'dead pixel',
#  'gay androids',
#  'low lifes',
#  'only ones',
#  'different function',
#  'bixby button',
#  'flashlight damn',
#  'severe upgrade',
#  'ridiculous ios',
#  'much lag',
#  'many bugs',
#  'clean smooth',
#  'much care',
#  'pretty colors',
#  "can't frame",
#  'headphone jack',
#  'nice phone',
#  'double-swipe notification',
#  'couple days',
#  'gonna lie',
#  'samsung person',
#  'next week',
#  'next year',
#  "noise what's",
#  'samsung financing',
#  "mine let's",
#  'big deal',
#  'new iphone',
#  'non-latex gloves',
#  'non latex',
#  's10 plus',
#  'ultrasonic fast',
#  'older tech',
#  'oppo rx09',
#  'mic closer',
#  'many things',
#  'better videos',
#  'fresh cut',
#  'screen protectors',
#  's9 s9',
#  'new gimmicks',
#  'wifi scanning',
#  'new finger',
#  'dry skin',
#  'print bit',
#  'other phones',
#  'fucking dream',
#  'frog please',
#  'only option',
#  'mobile data',
#  'quick toggle',
#  'configurable bixbi',
#  'sample piece',
#  'demo piece',
#  'new samsung',
#  'good work',
#  'sammy cough',
#  'same way',
#  'xr please',
#  'nokia pureview',
#  'lg g6',
#  'black screen',
#  'old news',
#  'tech reviewers',
#  'optical scanners',
#  'other phones',
#  'hard omg',
#  'wrong way',
#  'little haha',
#  'cheapest devices',
#  'get message',
#  'light notifications',
#  'weak ecosystem',
#  'good phone',
#  'good phone',
#  'first samsung',
#  'samsung spent',
#  'own devices',
#  'big time',
#  'different product',
#  'latest example',
#  'smart speaker',
#  'android phone',
#  'ridiculous though',
#  'long history',
#  'big deal',
#  'other coke',
#  'misguided email',
#  'weird get',
#  'ultrasonic finger',
#  'ultrassonic fingerprint',
#  'right way',
#  "don't press",
#  'same thing',
#  'many guys',
#  'same way',
#  'new skin',
#  'perfect samsung',
#  'imagine google',
#  'imagine world',
#  'unbox therapy',
#  'bixby button',
#  'tech market',
#  'other companies',
#  'solid color',
#  'ultrasonic fingerprint',
#  'touch whats',
#  's8 battery',
#  'ultrasonic fingerprint',
#  'right way',
#  'extra wack',
#  'older galaxy',
#  'double pull',
#  'new thing',
#  't-mobile carrier',
#  'unlocked phone',
#  'foldable samsung',
#  'inch tablet',
#  'good phone',
#  'big mistake',
#  'high end',
#  'next years',
#  'best upgrade',
#  'ultrasonic fingerprint',
#  'new kinda',
#  '4-5 year',
#  'only reason',
#  'android users',
#  'id settings',
#  'galaxy series',
#  'great videos',
#  'ikonik skin',
#  'blind person',
#  'dark mode',
#  'sony xperia',
#  'double pull',
#  'great vid',
#  'jealous iphone',
#  'new iphone',
#  'android phones',
#  's10e prism',
#  'awesome love',
#  'same thing',
#  'gonna switch',
#  'same thing',
#  'galaxy s10',
#  'double swipe',
#  'big step',
#  'huge play',
#  'shitty rainy',
#  'wet fingertips',
#  'actual problem',
#  'huge channel',
#  'inform people',
#  'big deal',
#  'serious diseases',
#  's10 thanks',
#  'punch yes',
#  'newest phone',
#  'fucking reason',
#  'quick charge',
#  'comedic timing',
#  'worst piece',
#  "apps it's",
#  'horrible witchcraft',
#  'screen protector',
#  'solid suggestions',
#  "i'm thinking",
#  'sonic sensor',
#  'nokia pure',
#  'awesome option',
#  'mean playing',
#  'loose chunk',
#  'first time',
#  'used market',
#  "that's deal",
#  'swipe notifications',
#  'dark mode',
#  'new hole',
#  'flat drops',
#  'more notification',
#  'same thing',
#  'double pull',
#  'wireless charge',
#  'other phones',
#  'asleep unlock',
#  'other people',
#  'samsung pay',
#  'key storage',
#  'next gen',
#  'front screen',
#  'better camera',
#  'more ram',
#  'green texts',
#  'unpacked event',
#  'ultrasonic fingerprint',
#  'more power',
#  'new phone',
#  'newest items',
#  'last phone',
#  'new ui',
#  "happy i've",
#  'oh yeah',
#  'dark mode',
#  'dark mode',
#  'stupid shit',
#  "most os's",
#  'same use',
#  'lesser security',
#  'awesome phone',
#  'most painters',
#  'useless feature',
#  'oneplus face',
#  'long line',
#  'different phones',
#  "i'll stick",
#  'same operating',
#  's-10 hmm',
#  'polar vantage',
#  'samsung beat',
#  'bixby button',
#  'mine s10',
#  "it's huawei",
#  'normal s10',
#  'normal version',
#  'usb charger',
#  'samsung galaxy',
#  'secondary swipe',
#  'pc sounds',
#  'whole bunch',
#  'dark mode',
#  'black lol',
#  'certain kind',
#  'secondary swipe',
#  'galaxy phones',
#  'same feature',
#  'favorite phone',
#  'nice device',
#  'u12 face',
#  'better look',
#  'previous ones',
#  'early apple',
#  'x-ray machine',
#  'nokia pureview',
#  'bad battery',
#  'simple features',
#  's9 shouldve',
#  'waited nightmare',
#  'bixby button',
#  'available date',
#  'ui features',
#  'new samsung',
#  'current phone',
#  'daily phone',
#  'old lg',
#  'old phone',
#  'slow face',
#  'a-la mute',
#  'best samsung',
#  'good buy',
#  'only thing',
#  'screen record',
#  'bixby button',
#  'dirty fingertips',
#  'android device',
#  'upgrade tho',
#  'upgrade im',
#  'best thing',
#  'only question',
#  "other didn't",
#  'bixby button',
#  'different app',
#  'dim-witted tech',
#  'snatch juices',
#  'unlimited power',
#  'worst review',
#  'i-ll switch',
#  'daily driver',
#  'ima razer',
#  'microsoft android',
#  's10 huhuhu',
#  'nokia motorola',
#  'oh man',
#  'immediate unlock',
#  'ios user',
#  'right phone',
#  'only reason',
#  'expensive phones',
#  'virus apple',
#  'india samsung',
#  's10 price',
#  'indian people',
#  'samsung s10',
#  'same features',
#  'awkward pauses',
#  "lewis i'd",
#  "won't samsung",
#  'same body',
#  'bigger display',
#  'galaxy s10',
#  "oneplus they'll",
#  'galaxy s10',
#  "best i'm",
#  's7 edge',
#  'ui10 nots',
#  'brawl stars',
#  'diff game',
#  'whole punch',
#  'older generation',
#  'original price',
#  'nice phone',
#  'same update',
#  'galaxy note',
#  'bixby button',
#  'download bxactions',
#  'new emojis',
#  'new chevy',
#  'homescreen button',
#  'haha s10',
#  "fine i'm",
#  'bullshit price',
#  'best advantage',
#  'phenomenal iphone',
#  'first feature',
#  'll look',
#  'huge hands',
#  'new software',
#  'good job',
#  'honest bit',
#  'iphone users',
#  'dark mode',
#  'ui gonna',
#  'previous models',
#  'secondary swipe',
#  'new emui',
#  'android ios',
#  'bixby button',
#  'weird asf',
#  'ne et',
#  'anniversary model',
#  'same type',
#  'super handy',
#  "much they'll",
#  'lookin fat',
#  'unbox therapy',
#  'false imaginary',
#  'horrible reputation',
#  'stupid prices',
#  'disposable income',
#  'im thats',
#  'legit feel',
#  'first time',
#  'full iphone',
#  'iphone user',
#  'xs max',
#  'cheapest cellphones',
#  'unlocked vs',
#  'first phone',
#  'assume re-do',
#  'ima laugh',
#  "hey i'll",
#  'bad phone',
#  'unbox huawei',
#  'unbox therapy',
#  'upcoming phones',
#  'exact designs',
#  'swipe feature',
#  'only one',
#  'giant icons',
#  'much experience',
#  'samsung phones',
#  'white backdrop',
#  'white looks',
#  'iphone look',
#  "old what's",
#  'facial recognition',
#  'greatest form',
#  'huawei mate',
#  'pro android',
#  'porn button',
#  'iris scanner',
#  'beautiful display',
#  'past years',
#  'guys weirdo',
#  'infinite power',
#  'have devices',
#  'new ui',
#  'crap thing',
#  'smaller notch',
#  'hole samsung',
#  'terrible wonder',
#  'lumia series',
#  'top notch',
#  'unlock response',
#  'dev mode',
#  'lower animation',
#  'black iphone',
#  'browser history',
#  'next gen',
#  'earned money',
#  'simple samsung',
#  'average phone',
#  'best choice',
#  'expensive power',
#  'xs max',
#  's10 plush',
#  'next iphone',
#  'long time',
#  "it's feature",
#  'like s10',
#  'tech features',
#  'dna scanner',
#  'best review',
#  'full screen',
#  'content ahhh',
#  'ass emojis',
#  "honest it's",
#  'samsung fit',
#  'porn lol',
#  'pseudo technobloggers',
#  "doesn't work",
#  'funny s10',
#  'defo buy',
#  'pro mode',
#  'small folks',
#  'reverse charging',
#  'important cause',
#  'sir please',
#  'ethical hackers',
#  'sir please',
#  'ethical hackers',
#  'old samsung',
#  'facial recognition',
#  'touch wiz',
#  'double camera',
#  'bixby button',
#  'ur finger',
#  'double drag',
#  'ui update',
#  "note9 i'm",
#  'left eye',
#  'great vedio',
#  'weird tht',
#  'waterproof s8',
#  'new ui',
#  'recent apps',
#  'powerful video',
#  'pie tweaks',
#  'touchwiz era',
#  'fast nice',
#  'longer defo',
#  'dark mode',
#  'dark mode',
#  'bixby button',
#  'bixby button',
#  'web page',
#  'oh cool',
#  'light theme',
#  'dark theme',
#  'dark theme',
#  'holy crap',
#  'secondary swipe',
#  "huawei it's",
#  'much samsung',
#  'biggest problem',
#  'recent reports',
#  'older phones',
#  'more time',
#  'old phones',
#  'useful thing',
#  'robust tech',
#  'll cop',
#  'cool haha',
#  'biometric sensor',
#  'unknown stuff',
#  'same software',
#  'im gonna',
#  'good phone',
#  'instant mute',
#  'certain kinda',
#  'new phone',
#  'expensive wish',
#  'poor people',
#  'unbox therapy',
#  'dont stop',
#  'pixel camera',
#  'further interaction',
#  'automotive oil',
#  'awkward silences',
#  'new innovation',
#  'download bxactions',
#  'other purposes',
#  'best setup',
#  'hate bixby',
#  'best android',
#  'pls feature',
#  'facial unlock',
#  'bad experiences',
#  'android pie',
#  'galaxy s10',
#  ...]

# %%
#creating the frequency distribution
word_dist=nltk.FreqDist(phrases)

# get the most frequent items
print("top 30 bigrams:", word_dist.most_common(30))
# Out:
# top 30 bigrams: [('new phone', 140), ('unbox therapy', 118), ('bixby button', 118), ('dark mode', 91), ('best phone', 80), ('ultrasonic fingerprint', 77), ('more ram', 73), ('long time', 68), ('only one', 66), ('same thing', 65), ('new samsung', 62), ('next video', 60), ('full screen', 59), ('screen protector', 56), ('only thing', 55), ('great video', 54), ('new phones', 52), ('foldable phone', 50), ('great phone', 49), ('facial recognition', 48), ('first time', 48), ('double swipe', 45), ('good phone', 45), ('new iphone', 44), ('last year', 42), ('cant wait', 40), ('next phone', 39), ('secondary swipe', 38), ('galaxy note', 38), ('wide angle', 38)]
